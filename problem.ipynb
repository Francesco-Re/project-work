# %%
import logging
from itertools import combinations
from Problem import Problem
from s343404 import solution

import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

from icecream import ic

# %% [markdown]
# Cost: $d + (d \cdot \alpha \cdot w)^\beta$ with $\alpha \ge 0$ and $\beta \ge 0$

# %%
P = Problem(10, density=0.2, alpha=1, beta=1)
P.plot()

# %%
logging.getLogger().setLevel(logging.WARNING)

problem = Problem(100, density=0.2, alpha=1, beta=1)
print(f"Problem(size=100, density=0.2, alpha=1, beta=1)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(100, density=0.2, alpha=2, beta=1)
print(f"\nProblem(size=100, density=0.2, alpha=2, beta=1)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(100, density=0.2, alpha=1, beta=2)    
print(f"\nProblem(size=100, density=0.2, alpha=1, beta=2)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(100, density=1, alpha=1, beta=1)
print(f"\nProblem(size=100, density=1, alpha=1, beta=1)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(100, density=1, alpha=2, beta=1)
print(f"\nProblem(size=100, density=1, alpha=2, beta=1)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(100, density=1, alpha=1, beta=2)
print(f"\nProblem(size=100, density=1, alpha=1, beta=2)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(1_000, density=0.2, alpha=1, beta=1)
print(f"\nProblem(size=1_000, density=0.2, alpha=1, beta=1)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(1_000, density=0.2, alpha=2, beta=1)
print(f"\nProblem(size=1_000, density=0.2, alpha=2, beta=1)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(1_000, density=0.2, alpha=1, beta=2)
print(f"\nProblem(size=1_000, density=0.2, alpha=1, beta=2)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(1_000, density=1, alpha=1, beta=1)
print(f"\nProblem(size=1_000, density=1, alpha=1, beta=1)")
ic(problem.baseline())
ic(solution(problem, True))

problem = Problem(1_000, density=1, alpha=2, beta=1)
print(f"\nProblem(size=1_000, density=1, alpha=2, beta=1)")
ic(problem.baseline())
ic(solution(problem, True))
    
problem = Problem(1_000, density=1, alpha=1, beta=2)
print(f"\nProblem(size=1_000, density=1, alpha=1, beta=2)")
ic(problem.baseline())
ic(solution(problem, True))
# Out:
# Problem(size=100, density=0.2, alpha=1, beta=1)
# ic| problem.baseline(): np.float64(25266.40561851072)
# ic| solution(problem, True): np.float64(25234.267677995173)
# ic| problem.baseline(): np.float64(50425.30961817918)
# Problem(size=100, density=0.2, alpha=2, beta=1)
# ic| solution(problem, True): np.float64(50393.840462133)
# ic| problem.baseline(): np.float64(5334401.927002504)
# ic| solution(problem, True): np.float64(5055108.685018502)
# ic| problem.baseline(): np.float64(18266.18579582672)
# Problem(size=100, density=0.2, alpha=1, beta=2)
#
# Problem(size=100, density=1, alpha=1, beta=1)
# ic| solution(problem, True): np.float64(18255.743272702493)
# ic| problem.baseline(): np.float64(36457.918462372065)
# ic| solution(problem, True): np.float64(36450.65181751365)
# ic| problem.baseline(): np.float64(5404978.08899582)
# Problem(size=100, density=1, alpha=2, beta=1)
#
# Problem(size=100, density=1, alpha=1, beta=2)
# ic| solution(problem, True): np.float64(4796301.380236631)
# ...
